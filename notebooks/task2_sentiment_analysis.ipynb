# %%
import pandas as pd
import re

# %%
df = pd.read_csv("../data/processed/reviews_cleaned.csv")

print("Rows:", len(df))
df.head()
# Out:
# Rows: 1200
#                                               review  rating  \
# 0                                                  ❤       5
# 1                                     its a goos app       5
# 2                                  Super-easy to use       5
# 3                                               best       5
# 4  It's great app but Please add(included) water ...       4
#
#                         date bank       source
# 0  2025-12-12 16:03:43+00:00  CBE  Google Play
# 1  2025-12-12 12:04:31+00:00  CBE  Google Play
# 2  2025-12-12 11:34:24+00:00  CBE  Google Play
# 3  2025-12-12 11:29:12+00:00  CBE  Google Play
# 4  2025-12-12 11:05:04+00:00  CBE  Google Play

# %%
def clean_text(text):
    if not isinstance(text, str):
        return ""
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s]', '', text)
    return text

# %%
df["clean_review"] = df["review"].apply(clean_text)

df[["review", "clean_review"]].head()
# Out:
#                                               review  \
# 0                                                  ❤
# 1                                     its a goos app
# 2                                  Super-easy to use
# 3                                               best
# 4  It's great app but Please add(included) water ...
#
#                                         clean_review
# 0
# 1                                     its a goos app
# 2                                   supereasy to use
# 3                                               best
# 4  its great app but please addincluded water bil...

# %%
from transformers import pipeline

sentiment_model = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english"
)
# Out:
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cpu

# %%
sentiments = sentiment_model(
    df["review"].fillna("").tolist(),
    truncation=True
)

df["sentiment_label"] = [s["label"] for s in sentiments]
df["sentiment_score"] = [s["score"] for s in sentiments]

df[["review", "sentiment_label", "sentiment_score"]].head()
# Out:
#                                               review sentiment_label  \
# 0                                                  ❤        NEGATIVE
# 1                                     its a goos app        NEGATIVE
# 2                                  Super-easy to use        POSITIVE
# 3                                               best        POSITIVE
# 4  It's great app but Please add(included) water ...        NEGATIVE
#
#    sentiment_score
# 0         0.697057
# 1         0.984296
# 2         0.997118
# 3         0.999794
# 4         0.903313

# %%
THEMES = {
    "Account Access": ["login", "password", "otp", "verification", "signin"],
    "Performance": ["slow", "crash", "freeze", "loading", "lag", "stuck"],
    "UI/UX": ["ui", "design", "interface", "navigation", "layout", "screen"],
    "Features": ["transfer", "payment", "bill", "feature", "fingerprint"],
    "Support": ["support", "service", "help", "call", "customer"]
}

# %%
def assign_theme(text):
    text = str(text).lower()
    for theme, keywords in THEMES.items():
        if any(k in text for k in keywords):
            return theme
    return "General"

# %%
df["theme"] = df["review"].apply(assign_theme)

df[["review", "theme"]].tail(10)
# Out:
#                                                  review     theme
# 1190  The Dashen Super App is very impressive. It is...     UI/UX
# 1191                                  betam kerfafa naw   General
# 1192                                        exceptional   General
# 1193                                     worst app ever   General
# 1194                     Dashen, always two step ahead.   General
# 1195  Please try to fix the barrier between other ba...   General
# 1196                                                  👍   General
# 1197                                         i am using   General
# 1198  It is a wonderful App developed by a local tal...  Features
# 1199                                      wonderful app   General

# %%
df.to_csv("../data/processed/analyzed_reviews.csv", index=False)

print("Saved analyzed_reviews.csv")
# Out:
# Saved analyzed_reviews.csv

# %%
df.groupby("bank")["sentiment_label"].value_counts(normalize=True)
# Out:
# bank    sentiment_label
# BOA     NEGATIVE           0.56
#         POSITIVE           0.44
# CBE     POSITIVE           0.66
#         NEGATIVE           0.34
# Dashen  POSITIVE           0.66
#         NEGATIVE           0.34
# Name: proportion, dtype: float64

# %%
df["theme"].value_counts()
# Out:
# theme
# General           1008
# Performance         52
# UI/UX               44
# Features            40
# Support             40
# Account Access      16
# Name: count, dtype: int64
